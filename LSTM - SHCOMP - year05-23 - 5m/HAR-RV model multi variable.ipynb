# %%
#import library
import pandas as pd
import numpy as np
import math
import utils
import statsmodels.api as sm

# %%
df_data_set = pd.read_csv('Data/shcmp multi variable for HAR.csv')
df_data_set['Date'] = pd.to_datetime(df_data_set['Date'])
df_data_set.set_index('Date', inplace=True)
df_data_set.head(5)
# Out:
#             Realized Volatility  Constant   RV_lag1    5MA_RV   22MA_RV  \
# Date
# 2005-02-03             3.711811         1  3.041918  1.114210  0.943433
# 2005-02-04             1.455927         1  3.711811  1.766252  1.082825
# 2005-02-16             1.203328         1  1.455927  1.968796  1.090226
# 2005-02-17             0.737522         1  1.203328  2.064023  1.122296
# 2005-02-18             0.478975         1  0.737522  2.030101  1.104006
#
#             Abs_Bias  squared_pct_chg  abs_overnight_info
# Date
# 2005-02-03  0.030942           5.3467            0.001048
# 2005-02-04  0.020110           0.8138            0.002981
# 2005-02-16  0.032456           2.1490            0.005510
# 2005-02-17  0.026108           0.7782            0.000897
# 2005-02-18  0.009802           0.2147            0.000368

# %%
X = df_data_set.drop('Realized Volatility',1)
Y = df_data_set['Realized Volatility']

# %% [markdown]
# Implementing HAR-RV model # by Corsi (2009)
#
# The HAR-RV model is a regression-based model that uses lagged realized volatility
#   as predictor variables to forecast the volatility of a financial asset.
#  The model assumes that the volatility of an asset depends on its own past volatility as
#  well as the past volatility of related assets and the overall market volatility.
#
#  RV_t = α_0 + α_1 RV_{t-1} + α_2 RV_{t-5} + α_3 RV_{t-22}  + ε_t

# %%
#Split the data into train set and test set
TEST_LEN = 439
Y_train, Y_test = Y[:-TEST_LEN], Y[-TEST_LEN:]
X_train, X_test = X[:-TEST_LEN], X[-TEST_LEN:]

# %%
X.shape, X_train.shape, Y_test.shape
# Out:
# ((4388, 7), (3949, 7), (439,))

# %%
# Start Linear regression
mod = sm.OLS(Y_train,X_train)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     Realized Volatility   R-squared:                       0.570
# Model:                             OLS   Adj. R-squared:                  0.569
# Method:                  Least Squares   F-statistic:                     871.4
# Date:                 Sun, 09 Apr 2023   Prob (F-statistic):               0.00
# Time:                         14:16:06   Log-Likelihood:                -7920.8
# No. Observations:                 3949   AIC:                         1.586e+04
# Df Residuals:                     3942   BIC:                         1.590e+04
# Df Model:                            6
# Covariance Type:             nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Constant              -0.4071      0.045     -9.038      0.000      -0.495      -0.319
# RV_lag1                0.2450      0.018     13.543      0.000       0.210       0.280
# 5MA_RV                 0.2710      0.028      9.520      0.000       0.215       0.327
# 22MA_RV                0.1545      0.027      5.778      0.000       0.102       0.207
# Abs_Bias              37.7960      3.244     11.652      0.000      31.436      44.156
# squared_pct_chg        0.3098      0.033      9.334      0.000       0.245       0.375
# abs_overnight_info    35.7133      5.256      6.794      0.000      25.408      46.019
# ==============================================================================
# Omnibus:                     4136.132   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           438392.526
# Skew:                           5.030   Prob(JB):                         0.00
# Kurtosis:                      53.627   Cond. No.                         895.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_pred = res.predict(X_test)

# %%
utils.Predictions_Error(Predictions_val=y_pred,Actual_val=Y_test)
# Out:
# MAE =  0.3711118503882987
# MSE =  0.30852235922491666
# RMSE =  0.5554478906476437
# R_2 =  0.1689441324711457
# RMSPE =  1.1375749089885934
# MSLE =  0.07894290601932226

# %% [markdown]
# MAE =  0.30221074598776043
# MSE =  0.2546077265064707
# RMSE =  0.5045866887923924
# R_2 =  0.3123796859147281
# RMSPE =  0.9269844040011631
# MSLE =  0.04782273607008992

# %%
utils.plot_figure(y_pred,Y_test)

# %%
train_pred = res.predict(X_train)

# %%
utils.plot_figure(data=train_pred,data2=Y_train)

# %%
utils.Predictions_Error(Predictions_val=train_pred,Actual_val=Y_train)
# Out:
# MAE =  0.7979512346517873
# MSE =  3.6884765848300236
# RMSE =  1.9205407011646547
# R_2 =  0.5088291924540984
# RMSPE =  1.0077596480828324
# MSLE =  0.09895415886722511
