# %%
#Learn Code from 
#https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/
#Author: Jason Brownlee

#import library
import pandas as pd
import numpy as np
import math
import utils
from matplotlib import pyplot as plt

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
df_data_set = pd.read_csv('Data/shcmp multi variable.csv')
df_data_set.set_index('Date',inplace=True)
df_data_set.head(5)
len(df_data_set)
# Out:
# 4410

# %%
# plot each column
Variables = df_data_set.columns
plt.figure(figsize=(12,8))
for group in range(len(Variables)):
 plt.subplot(len(Variables), 1, group+1)
 plt.plot(df_data_set.values[:, group])
 plt.title(df_data_set.columns[group], y=0.7, loc='right')
plt.show()

# %%
def df_to_X_y3(df, window_size=7):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size][0]
    y.append(label)
  return np.array(X), np.array(y)

# %%
#Set Windows size here
WINDOWS_SIZE = 20
X,y = df_to_X_y3(df_data_set, window_size = WINDOWS_SIZE)

X.shape,y.shape
# Out:
# ((4390, 20, 4), (4390,))

# %%
#Convert the data into training set, validation set and test set
#The number percentage of each set is 80%, 10% and 10%

#OR CUSTOMIZE YOUR PERCENTAGE OF EACH SET HERE
TRAINING_DATA_LEN = math.ceil(len(X)*0.8)
VALIDATION_LEN = math.ceil(len(X)*0.9)

X_train, y_train, X_val, y_val, X_test, y_test = utils.split_to_training_val_test(X,y,\
    training_len=TRAINING_DATA_LEN, val_len=VALIDATION_LEN)

#check size of each set
X_train.shape, X_test.shape, X_val.shape,y_test.shape,y_train.shape,y_test.shape
# Out:
# ((3512, 20, 4), (439, 20, 4), (439, 20, 4), (439,), (3512,), (439,))

# %%
#built model_multi for multi variate LSTM
model_multi = Sequential()
model_multi.add(InputLayer((X_train.shape[1], X_train.shape[2])))
model_multi.add(LSTM(64, dropout=0.1))
model_multi.add(Dense(1, 'linear'))

model_multi.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 64)                17664
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 17,729
# Trainable params: 17,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('model_multi/', save_best_only=True)
model_multi.compile(loss=MeanSquaredError(), \
              optimizer=Adam(learning_rate=0.005), metrics=[RootMeanSquaredError()])

# %%
#Set Epoch here
EPOCH = 30

#Start to train model
history = model_multi.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=EPOCH, callbacks=[cp])
# Out:
# Epoch 1/30
# 110/110 [==============================] - 7s 28ms/step - loss: 4.6872 - root_mean_squared_error: 2.1650 - val_loss: 0.4864 - val_root_mean_squared_error: 0.6974
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_multi\assets
# INFO:tensorflow:Assets written to: model_multi\assets
# Epoch 2/30
# 110/110 [==============================] - 2s 19ms/step - loss: 4.1134 - root_mean_squared_error: 2.0282 - val_loss: 0.2917 - val_root_mean_squared_error: 0.5401
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_multi\assets
# INFO:tensorflow:Assets written to: model_multi\assets
# Epoch 3/30
# 110/110 [==============================] - 2s 18ms/step - loss: 3.9785 - root_mean_squared_error: 1.9946 - val_loss: 0.3358 - val_root_mean_squared_error: 0.5795
# Epoch 4/30
# 110/110 [==============================] - 2s 17ms/step - loss: 3.6592 - root_mean_squared_error: 1.9129 - val_loss: 0.3321 - val_root_mean_squared_error: 0.5763
# Epoch 5/30
# 110/110 [==============================] - 2s 18ms/step - loss: 3.4657 - root_mean_squared_error: 1.8616 - val_loss: 0.4247 - val_root_mean_squared_error: 0.6517
# Epoch 6/30
# 110/110 [==============================] - 2s 16ms/step - loss: 3.7547 - root_mean_squared_error: 1.9377 - val_loss: 0.3925 - val_root_mean_squared_error: 0.6265
# Epoch 7/30
# 110/110 [==============================] - 2s 17ms/step - loss: 3.2866 - root_mean_squared_error: 1.8129 - val_loss: 0.4209 - val_root_mean_squared_error: 0.6488
# Epoch 8/30
# 110/110 [==============================] - 2s 17ms/step - loss: 3.2854 - root_mean_squared_error: 1.8126 - val_loss: 0.4033 - val_root_mean_squared_error: 0.6351
# Epoch 9/30
# 110/110 [==============================] - 2s 17ms/step - loss: 3.0732 - root_mean_squared_error: 1.7531 - val_loss: 0.4803 - val_root_mean_squared_error: 0.6930
# Epoch 10/30
# 110/110 [==============================] - 2s 17ms/step - loss: 3.2293 - root_mean_squared_error: 1.7970 - val_loss: 0.3656 - val_root_mean_squared_error: 0.6046
# Epoch 11/30
# 110/110 [==============================] - 2s 17ms/step - loss: 2.9768 - root_mean_squared_error: 1.7253 - val_loss: 0.3607 - val_root_mean_squared_error: 0.6006
# Epoch 12/30
# 110/110 [==============================] - 2s 19ms/step - loss: 3.0532 - root_mean_squared_error: 1.7474 - val_loss: 0.4349 - val_root_mean_squared_error: 0.6595
# Epoch 13/30
# 110/110 [==============================] - 2s 17ms/step - loss: 3.0022 - root_mean_squared_error: 1.7327 - val_loss: 0.3337 - val_root_mean_squared_error: 0.5777
# Epoch 14/30
# 110/110 [==============================] - 2s 17ms/step - loss: 3.2801 - root_mean_squared_error: 1.8111 - val_loss: 0.4094 - val_root_mean_squared_error: 0.6399
# Epoch 15/30
# 110/110 [==============================] - 2s 17ms/step - loss: 2.8259 - root_mean_squared_error: 1.6810 - val_loss: 0.3172 - val_root_mean_squared_error: 0.5632
# Epoch 16/30
# 110/110 [==============================] - 2s 17ms/step - loss: 3.0272 - root_mean_squared_error: 1.7399 - val_loss: 0.4316 - val_root_mean_squared_error: 0.6570
# Epoch 17/30
# 110/110 [==============================] - 2s 17ms/step - loss: 2.5731 - root_mean_squared_error: 1.6041 - val_loss: 0.4366 - val_root_mean_squared_error: 0.6607
# Epoch 18/30
# 110/110 [==============================] - 2s 18ms/step - loss: 2.7949 - root_mean_squared_error: 1.6718 - val_loss: 0.3612 - val_root_mean_squared_error: 0.6010
# Epoch 19/30
# 110/110 [==============================] - 2s 18ms/step - loss: 2.6323 - root_mean_squared_error: 1.6224 - val_loss: 0.4309 - val_root_mean_squared_error: 0.6564
# Epoch 20/30
# 110/110 [==============================] - 2s 17ms/step - loss: 2.8403 - root_mean_squared_error: 1.6853 - val_loss: 0.3013 - val_root_mean_squared_error: 0.5489
# Epoch 21/30
# 110/110 [==============================] - 2s 17ms/step - loss: 2.6564 - root_mean_squared_error: 1.6299 - val_loss: 0.3942 - val_root_mean_squared_error: 0.6279
# Epoch 22/30
# 110/110 [==============================] - 2s 17ms/step - loss: 2.6369 - root_mean_squared_error: 1.6239 - val_loss: 0.3172 - val_root_mean_squared_error: 0.5632
# Epoch 23/30
# 110/110 [==============================] - 2s 17ms/step - loss: 2.4773 - root_mean_squared_error: 1.5739 - val_loss: 0.3029 - val_root_mean_squared_error: 0.5503
# Epoch 24/30
# 110/110 [==============================] - 2s 18ms/step - loss: 2.4869 - root_mean_squared_error: 1.5770 - val_loss: 0.3559 - val_root_mean_squared_error: 0.5966
# Epoch 25/30
# 110/110 [==============================] - 2s 18ms/step - loss: 2.3776 - root_mean_squared_error: 1.5420 - val_loss: 0.3707 - val_root_mean_squared_error: 0.6088
# Epoch 26/30
# 110/110 [==============================] - 2s 17ms/step - loss: 2.4531 - root_mean_squared_error: 1.5662 - val_loss: 0.3791 - val_root_mean_squared_error: 0.6157
# Epoch 27/30
# 110/110 [==============================] - 2s 18ms/step - loss: 2.6779 - root_mean_squared_error: 1.6364 - val_loss: 0.3991 - val_root_mean_squared_error: 0.6317
# Epoch 28/30
# 110/110 [==============================] - 2s 18ms/step - loss: 2.4319 - root_mean_squared_error: 1.5595 - val_loss: 0.3639 - val_root_mean_squared_error: 0.6033
# Epoch 29/30
# 110/110 [==============================] - 2s 17ms/step - loss: 2.4479 - root_mean_squared_error: 1.5646 - val_loss: 0.3114 - val_root_mean_squared_error: 0.5580
# Epoch 30/30
# 110/110 [==============================] - 2s 18ms/step - loss: 2.1052 - root_mean_squared_error: 1.4509 - val_loss: 0.3325 - val_root_mean_squared_error: 0.5766

# %%
# plot history
#plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

min(history.history['val_loss'])
# Out:
# 0.2916560471057892

# %%
from tensorflow.keras.models import load_model
#check result for training set
model1 = load_model('model_multi/')
train_predictions = model1.predict(X_test).flatten()

# %%
train_results = pd.read_csv('Data/date.csv')
train_results['Date'] = pd.to_datetime(train_results['Date'])
train_results.set_index('Date',inplace=True)

train_results['Train Predictions'] = train_predictions

# %%
train_results.head(5)
# Out:
#             Realized Volatility  Train Predictions
# Date
# 2021-05-11             0.794308           0.314897
# 2021-05-12             0.480160           0.335618
# 2021-05-13             0.647137           0.318309
# 2021-05-14             0.489060           0.484303
# 2021-05-17             0.423597           0.456884

# %%
plt.figure(figsize=(12,8))
plt.plot(train_results['Train Predictions'], label='LSTM+BRO*')
plt.plot(train_results['Realized Volatility'], label='Realized Volatility',linestyle=':')
plt.xlabel('Date')
plt.ylabel('Realized Volatility')
plt.legend()
plt.show()

# %%
#show error
Predictions_val = train_results['Train Predictions']
Actual_val = train_results['Realized Volatility']

utils.Predictions_Error(Predictions_val,Actual_val)
# Out:
# MAE =  0.275980788345344
# MSE =  0.21229480163746273
# RMSE =  0.4607546002347266
# R_2 =  0.42814893225269035
# RMSPE =  0.6045622718135457
# MSLE =  0.05012665406067921
